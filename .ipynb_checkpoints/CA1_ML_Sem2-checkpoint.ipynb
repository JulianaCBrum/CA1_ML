# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("airline_2019.csv")

# %%
df.head()
# Out:
#       FL_DATE  OP_CARRIER_AIRLINE_ID TAIL_NUM ORIGIN ORIGIN_CITY_NAME  \
# 0  2019-04-01                  20416   N605NK    BWI    Baltimore, MD
# 1  2019-04-01                  20416   N605NK    DTW      Detroit, MI
# 2  2019-04-01                  20416   N605NK    BWI    Baltimore, MD
# 3  2019-04-01                  20416   N605NK    MCO      Orlando, FL
# 4  2019-04-01                  20416   N637NK    LAS    Las Vegas, NV
#
#   ORIGIN_STATE_NM DEST DEST_CITY_NAME DEST_STATE_NM  CRS_DEP_TIME  ...  \
# 0        Maryland  MCO    Orlando, FL       Florida          1020  ...
# 1        Michigan  BWI  Baltimore, MD      Maryland           755  ...
# 2        Maryland  DTW    Detroit, MI      Michigan          1931  ...
# 3         Florida  BWI  Baltimore, MD      Maryland          1623  ...
# 4          Nevada  DTW    Detroit, MI      Michigan          2320  ...
#
#    ARR_TIME  CANCELLED  CANCELLATION_CODE  DIVERTED  CARRIER_DELAY  \
# ...

# %%
df.shape
# Out:
# (7373570, 26)

# %%
df.tail()
# Out:
#             FL_DATE  OP_CARRIER_AIRLINE_ID TAIL_NUM ORIGIN   ORIGIN_CITY_NAME  \
# 7373565  2019-03-31                  19930   N524VA    SFO  San Francisco, CA
# 7373566  2019-03-31                  19930   N529VA    SAN      San Diego, CA
# 7373567  2019-03-31                  19930   N528VA    SFO  San Francisco, CA
# 7373568  2019-03-31                  19930   N524VA    SAN      San Diego, CA
# 7373569  2019-03-31                  19930   N364VA    SFO  San Francisco, CA
#
#         ORIGIN_STATE_NM DEST     DEST_CITY_NAME DEST_STATE_NM  CRS_DEP_TIME  \
# 7373565      California  SAN      San Diego, CA    California          1830
# 7373566      California  SFO  San Francisco, CA    California          1740
# 7373567      California  SAN      San Diego, CA    California          2140
# 7373568      California  SFO  San Francisco, CA    California          2050
# 7373569      California  LAX    Los Angeles, CA    California          1100
#
# ...

# %%
df2=pd.read_csv("Transportation_To_Work_2000-2006-2010.csv")
# Out:
# C:\Users\barba\AppData\Local\Temp\ipykernel_33036\690973125.py:1: DtypeWarning: Columns (3,8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv("Transportation_To_Work_2000-2006-2010.csv")

# %%
df2.shape
# Out:
# (336238, 25)

# %%
df2.head()
# Out:
#    index  ind_id                                     ind_definition  \
# 0      0      42  Percent of residents aged 16 years and older m...
# 1      1      42  Percent of residents aged 16 years and older m...
# 2      2      42  Percent of residents aged 16 years and older m...
# 3      3      42  Percent of residents aged 16 years and older m...
# 4      4      42  Percent of residents aged 16 years and older m...
#
#   reportyear  race_eth_code race_eth_name geotype  geotypevalue     geoname  \
# 0       2000              1          AIAN      CA             6  California
# 1       2000              2         Asian      CA             6  California
# 2       2000              3     AfricanAm      CA             6  California
# 3       2000              4        Latino      CA             6  California
# 4       2000              5         NHOPI      CA             6  California
#
#   county_name  ...  pop_mode  pop_total   percent LL95CI_percent  \
# ...

# %%
df3=pd.read_csv("Electric_Vehicle_Population_Data.csv")

# %%
df3.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year   Make  \
# 0  5YJ3E1EB4L     Yakima     Yakima    WA      98908.0        2020  TESLA
# 1  5YJ3E1EA7K  San Diego  San Diego    CA      92101.0        2019  TESLA
# 2  7JRBR0FL9M       Lane     Eugene    OR      97404.0        2021  VOLVO
# 3  5YJXCBE21K     Yakima     Yakima    WA      98908.0        2019  TESLA
# 4  5UXKT0C5XH  Snohomish    Bothell    WA      98021.0        2017    BMW
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL 3          Battery Electric Vehicle (BEV)
# 1  MODEL 3          Battery Electric Vehicle (BEV)
# 2      S60  Plug-in Hybrid Electric Vehicle (PHEV)
# 3  MODEL X          Battery Electric Vehicle (BEV)
# 4       X5  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             322
# 1           Clean Alternative Fuel Vehicle Eligible             220
# ...

# %%
df3.shape
# Out:
# (124716, 17)
