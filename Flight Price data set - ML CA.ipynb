# %% [markdown]
# # _HDIP Data Analytics_
#
# ### Machine Learning for Business
# Lecturer(s): Dr. Muhammad Iqbal
# Submission Deadline Date: 5th November 2023
#
# Students: **_Bárbara Abreu Costa 2023099_** | **_Juliana Cristina da Cunha Brum 2023021_**

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv('business.csv')

# %%
df.head()
# Out:
#          date    airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  Air India      AI       868    18:00  Delhi    02h 00m
# 1  11-02-2022  Air India      AI       624    19:00  Delhi    02h 15m
# 2  11-02-2022  Air India      AI       531    20:00  Delhi    24h 45m
# 3  11-02-2022  Air India      AI       839    21:25  Delhi    26h 30m
# 4  11-02-2022  Air India      AI       544    17:15  Delhi    06h 40m
#
#                                                 stop arr_time      to   price
# 0                                          non-stop     20:00  Mumbai  25,612
# 1                                          non-stop     21:15  Mumbai  25,612
# 2  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45  Mumbai  42,220
# 3  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  44,450
# 4  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  46,690

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93487 entries, 0 to 93486
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        93487 non-null  object
#  1   airline     93487 non-null  object
#  2   ch_code     93487 non-null  object
#  3   num_code    93487 non-null  int64
#  4   dep_time    93487 non-null  object
#  5   from        93487 non-null  object
#  6   time_taken  93487 non-null  object
#  7   stop        93487 non-null  object
#  8   arr_time    93487 non-null  object
#  9   to          93487 non-null  object
#  10  price       93487 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 7.8+ MB

# %%
df.head(-20)
# Out:
#               airline dep_time     from time_taken  \
# date
# 2022-11-02  Air India    18:00    Delhi    02h 00m
# 2022-11-02  Air India    19:00    Delhi    02h 15m
# 2022-11-02  Air India    20:00    Delhi    24h 45m
# 2022-11-02  Air India    21:25    Delhi    26h 30m
# 2022-11-02  Air India    17:15    Delhi    06h 40m
# ...               ...      ...      ...        ...
# 2022-03-31    Vistara    21:05  Chennai    12h 20m
# 2022-03-31    Vistara    07:05  Chennai    12h 45m
# 2022-03-31    Vistara    21:05  Chennai    15h 30m
# 2022-03-31    Vistara    07:05  Chennai    15h 50m
# 2022-03-31    Vistara    17:25  Chennai    16h 00m
#
#                                                          stop arr_time  \
# date
# 2022-11-02                                          non-stop     20:00
# 2022-11-02                                          non-stop     21:15
# 2022-11-02  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45
# 2022-11-02  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55
# 2022-11-02  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55
# ...                                                       ...      ...
# 2022-03-31  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:25
# 2022-03-31  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50
# 2022-03-31  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    12:35
# 2022-03-31  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    22:55
# 2022-03-31  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:25
#
#                    to  price
# date
# 2022-11-02     Mumbai  25612
# 2022-11-02     Mumbai  25612
# 2022-11-02     Mumbai  42220
# 2022-11-02     Mumbai  44450
# 2022-11-02     Mumbai  46690
# ...               ...    ...
# 2022-03-31  Hyderabad  51457
# 2022-03-31  Hyderabad  51457
# 2022-03-31  Hyderabad  51457
# 2022-03-31  Hyderabad  51457
# 2022-03-31  Hyderabad  51457
#
# [93467 rows x 8 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# Set the "Date" column as the index
df.set_index('date', inplace=True)

# Now, the "Date" column is the index
df.head()
# Out:
# C:\Users\jujub\AppData\Local\Temp\ipykernel_11196\2791475449.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date'] = pd.to_datetime(df['date'])
#               airline ch_code  num_code dep_time   from time_taken  \
# date
# 2022-11-02  Air India      AI       868    18:00  Delhi    02h 00m
# 2022-11-02  Air India      AI       624    19:00  Delhi    02h 15m
# 2022-11-02  Air India      AI       531    20:00  Delhi    24h 45m
# 2022-11-02  Air India      AI       839    21:25  Delhi    26h 30m
# 2022-11-02  Air India      AI       544    17:15  Delhi    06h 40m
#
#                                                          stop arr_time  \
# date
# 2022-11-02                                          non-stop     20:00
# 2022-11-02                                          non-stop     21:15
# 2022-11-02  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45
# 2022-11-02  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55
# 2022-11-02  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55
#
#                 to   price
# date
# 2022-11-02  Mumbai  25,612
# 2022-11-02  Mumbai  25,612
# 2022-11-02  Mumbai  42,220
# 2022-11-02  Mumbai  44,450
# 2022-11-02  Mumbai  46,690

# %%
df.drop(['ch_code', 'num_code'], axis=1, inplace=True)

df.head()
# Out:
#               airline dep_time   from time_taken  \
# date
# 2022-11-02  Air India    18:00  Delhi    02h 00m
# 2022-11-02  Air India    19:00  Delhi    02h 15m
# 2022-11-02  Air India    20:00  Delhi    24h 45m
# 2022-11-02  Air India    21:25  Delhi    26h 30m
# 2022-11-02  Air India    17:15  Delhi    06h 40m
#
#                                                          stop arr_time  \
# date
# 2022-11-02                                          non-stop     20:00
# 2022-11-02                                          non-stop     21:15
# 2022-11-02  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45
# 2022-11-02  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55
# 2022-11-02  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55
#
#                 to   price
# date
# 2022-11-02  Mumbai  25,612
# 2022-11-02  Mumbai  25,612
# 2022-11-02  Mumbai  42,220
# 2022-11-02  Mumbai  44,450
# 2022-11-02  Mumbai  46,690

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93487 entries, 2022-11-02 to 2022-03-31
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   airline     93487 non-null  object
#  1   dep_time    93487 non-null  object
#  2   from        93487 non-null  object
#  3   time_taken  93487 non-null  object
#  4   stop        93487 non-null  object
#  5   arr_time    93487 non-null  object
#  6   to          93487 non-null  object
#  7   price       93487 non-null  object
# dtypes: object(8)
# memory usage: 6.4+ MB

# %%
df['price'] = df['price'].str.replace('[\$,]', '', regex=True)

# Step 2: Convert the 'Price' column to numerical values
df['price'] = pd.to_numeric(df['price'])

df.head()
# Out:
#               airline dep_time   from time_taken  \
# date
# 2022-11-02  Air India    18:00  Delhi    02h 00m
# 2022-11-02  Air India    19:00  Delhi    02h 15m
# 2022-11-02  Air India    20:00  Delhi    24h 45m
# 2022-11-02  Air India    21:25  Delhi    26h 30m
# 2022-11-02  Air India    17:15  Delhi    06h 40m
#
#                                                          stop arr_time  \
# date
# 2022-11-02                                          non-stop     20:00
# 2022-11-02                                          non-stop     21:15
# 2022-11-02  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45
# 2022-11-02  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55
# 2022-11-02  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55
#
#                 to  price
# date
# 2022-11-02  Mumbai  25612
# 2022-11-02  Mumbai  25612
# 2022-11-02  Mumbai  42220
# 2022-11-02  Mumbai  44450
# 2022-11-02  Mumbai  46690

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 93487 entries, 2022-11-02 to 2022-03-31
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   airline     93487 non-null  object
#  1   dep_time    93487 non-null  object
#  2   from        93487 non-null  object
#  3   time_taken  93487 non-null  object
#  4   stop        93487 non-null  object
#  5   arr_time    93487 non-null  object
#  6   to          93487 non-null  object
#  7   price       93487 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 6.4+ MB

# %%
df.plot()
# Out:
# <Axes: xlabel='date'>
